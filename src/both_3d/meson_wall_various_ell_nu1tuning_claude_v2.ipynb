# %%
import h5py
import os
import numpy as np
import math
import matplotlib.pyplot as plt

import scipy as sp
import scipy.linalg
import scipy.optimize

import glob

from natsort import natsorted

# %%
class Jackknife:
    def __init__( self, len_data, binsize ):
        self.binsize = binsize
        self.nbins = math.floor( len_data/self.binsize )
        self.N = self.binsize * self.nbins
        self.jack_avg = []
        self.est = 0
        self.var_est = 0

    def set( self, func, list_of_data ):
        for i in range( self.nbins ):
            self.jack_avg.append( func( i, self.binsize, list_of_data ) )

    def do_it( self ):
        for i in range( 0, self.nbins ):
            self.est += self.jack_avg[i]
        self.est /= self.nbins

        for i in range( 0, self.nbins ):
            self.var_est += ( self.jack_avg[i] - self.est )**2
        self.var_est /= self.nbins
        self.var_est *= self.nbins -1

    def mean( self ):
        return self.est

    def var( self ):
        return self.var_est

    def err( self ):
        return np.sqrt(self.var_est)

def simple_mean(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    return np.mean(resmpld, axis=0)

def jack_avg(i, binsize, np_data):
    return np_data[i]

def take_abs(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    mean = np.mean(resmpld, axis=0)
    # mean = mean[1:int(Nt/2)] + np.flip( mean[int(Nt/2):Nt-1], axis=0 )

    return np.sqrt(mean.T[1]**2 + mean.T[2]**2)


def take_real(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    mean = np.mean(resmpld, axis=0)
    # mean = mean[1:int(Nt/2)] + np.flip( mean[int(Nt/2):Nt-1], axis=0 )
    return mean.T[1]

def take_imag(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    mean = np.mean(resmpld, axis=0)
    # mean = mean[1:int(Nt/2)] + np.flip( mean[int(Nt/2):Nt-1], axis=0 )
    return mean.T[2]


def format_print(cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'

def format_print_w_exact(exact, cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'+': '+'{num:.{width}f}'.format(num=(exact-cen)/err, width=i+1)+' sigma'

# %%
gsq = "8.000000"
at  = "0.200000"
Nt  = 128
L   = 1

Nf  = 2

# nu1_list = ["1.500000", "1.750000", "2.000000", "2.250000", "2.500000", "2.750000"]
nu0_list = ["1.000000", "1.500000"]

# %%
# only t0=0 and h=0 for this run (dt=128=Nt, nhits=1)
t0_list = [0]
h_list  = [0]

# %%
dir1='/mnt/barracuda22/qed3/qed3/src/both_3d/'

# %%
# corrs[nu1] = np.array, shape (n_configs, Nt) — real part, averaged over h/t0
corrs = {}

ell = 0
em  = 0
ab  = 3

for nu0 in nu0_list:
  label = "data_Nf"+str(Nf)+"_gsq"+gsq+"at"+at+"nu0"+nu0+"nu1"+nu0+"nt"+str(Nt)+"L"+str(L)
  path  = dir1 + label + "/"
  files = natsorted(glob.glob(path + "meson_corr_v2.*.h5"))
  data_ = []
  for fname in files:
      print( fname )
      with h5py.File(fname, 'r') as f:
          arr = np.zeros(Nt)
          for h in h_list:
              for t0 in t0_list:
                  ds = str(ell)+"/"+str(em)+"/"+str(ab)+"/"+str(h)+"/"+str(t0)+"/"
                  arr += f[ds+"real"][:]
          arr /= (len(h_list) * len(t0_list))
          data_.append(arr)
  corrs[nu0] = np.array(data_)
  print(nu0, corrs[nu0].shape)
# Out:
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.10.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.20.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.30.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.40.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.50.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.60.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.70.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.80.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.90.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.100.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.110.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.120.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.130.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.140.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.150.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.160.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.170.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.180.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.190.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.200.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.210.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.220.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.230.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.240.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.250.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.260.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.270.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.280.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.290.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.300.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.310.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.320.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.330.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.340.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.350.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.360.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.370.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.380.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.390.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.400.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.410.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.420.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.430.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.440.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.450.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.460.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.470.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.480.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.490.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.500.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.510.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.520.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.530.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.540.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.550.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.560.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.570.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.580.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.590.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.600.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.610.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.620.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.630.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.640.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.650.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.660.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.670.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.680.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.690.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.700.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.710.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.720.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.730.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.740.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.750.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.760.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.770.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.780.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.790.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.800.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.810.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.820.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.830.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.840.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.850.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.860.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.870.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.880.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.890.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.900.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.910.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.920.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.930.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.940.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.950.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.960.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.970.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.980.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.000000nu11.000000nt128L1/meson_corr_v2.990.h5
# 1.000000 (99, 128)
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.10.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.20.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.30.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.40.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.50.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.60.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.70.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.80.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.90.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.100.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.110.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.120.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.130.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.140.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.150.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.160.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.170.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.180.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.190.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.200.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.210.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.220.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.230.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.240.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.250.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.260.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.270.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.280.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.290.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.300.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.310.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.320.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.330.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.340.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.350.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.360.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.370.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.380.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.390.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.400.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.410.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.420.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.430.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.440.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.450.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.460.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.470.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.480.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.490.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.500.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.510.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.520.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.530.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.540.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.550.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.560.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.570.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.580.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.590.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.600.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.610.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.620.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.630.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.640.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.650.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.660.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.670.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.680.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.690.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.700.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.710.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.720.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.730.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.740.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.750.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.760.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.770.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.780.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.790.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.800.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.810.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.820.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.830.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.840.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.850.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.860.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.870.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.880.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.890.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.900.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.910.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.920.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.930.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.940.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.950.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.960.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.970.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.980.h5
# /mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq8.000000at0.200000nu01.500000nu11.500000nt128L1/meson_corr_v2.990.h5
# 1.500000 (99, 128)

# %%
nu0 = nu0_list[0]

# %%
np.mean( corrs[ nu0 ], axis=0 )
# Out:
# array([5.19946343e-01, 2.77953578e-02, 6.13598979e-03, 2.10556834e-03,
#        8.88803787e-04, 4.27745710e-04, 2.23790845e-04, 1.23367803e-04,
#        7.09419778e-05, 4.24182639e-05, 2.60398811e-05, 1.63789362e-05,
#        1.06121642e-05, 6.97279056e-06, 4.61263143e-06, 3.11560910e-06,
#        2.12237696e-06, 1.45078798e-06, 1.00780159e-06, 7.02843580e-07,
#        4.94363613e-07, 3.51858072e-07, 2.49192966e-07, 1.78139417e-07,
#        1.28156075e-07, 9.25381766e-08, 6.67458977e-08, 4.77516506e-08,
#        3.51176517e-08, 2.52345803e-08, 1.84834974e-08, 1.33914225e-08,
#        9.86523547e-09, 7.22634596e-09, 5.33012274e-09, 3.96473183e-09,
#        2.92385286e-09, 2.17165033e-09, 1.61176855e-09, 1.21047655e-09,
#        9.18032279e-10, 6.92738226e-10, 5.20731904e-10, 3.85279964e-10,
#        2.87209429e-10, 2.18390982e-10, 1.65926662e-10, 1.25905234e-10,
#        9.30795055e-11, 6.87456656e-11, 5.19705012e-11, 4.00484416e-11,
#        3.08386808e-11, 2.32586896e-11, 1.77843512e-11, 1.37660939e-11,
#        1.07278202e-11, 8.36365290e-12, 6.48938183e-12, 5.15369312e-12,
#        4.13811472e-12, 3.48263388e-12, 3.01915792e-12, 2.77683120e-12,
#        2.74463897e-12, 2.86564399e-12, 3.15060759e-12, 3.62762184e-12,
#        4.41847354e-12, 5.49181039e-12, 6.88095992e-12, 8.71715963e-12,
#        1.13588423e-11, 1.47760006e-11, 1.92418549e-11, 2.57703346e-11,
#        3.49490775e-11, 4.70798377e-11, 6.20724279e-11, 7.96074224e-11,
#        1.05411721e-10, 1.37216508e-10, 1.82115380e-10, 2.39111821e-10,
#        3.11846817e-10, 4.08523527e-10, 5.37902815e-10, 7.16518401e-10,
#        9.46861045e-10, 1.26724742e-09, 1.69562302e-09, 2.25947592e-09,
#        2.99301176e-09, 3.98870466e-09, 5.32148250e-09, 7.20829347e-09,
#        9.85617655e-09, 1.33067510e-08, 1.81339037e-08, 2.49094967e-08,
#        3.46514400e-08, 4.77600715e-08, 6.50859073e-08, 9.00887605e-08,
#        1.24322128e-07, 1.73283181e-07, 2.38116032e-07, 3.36344428e-07,
#        4.71178496e-07, 6.73559929e-07, 9.77600221e-07, 1.42878625e-06,
#        2.09951523e-06, 3.11967299e-06, 4.69307955e-06, 7.15282382e-06,
#        1.09713939e-05, 1.70045641e-05, 2.64871002e-05, 4.25693552e-05,
#        7.17140525e-05, 1.23402958e-04, 2.22660138e-04, 4.25755957e-04,
#        8.83990406e-04, 2.08710957e-03, 6.15944887e-03, 2.78452181e-02])

# %%
xxx = float(at) * np.arange(Nt)

# %%
for nu0 in nu0_list[:3]:
    plt.plot( xxx, np.mean( corrs[ nu0 ], axis=0 ),
            label='nu0='+nu0)

plt.plot( xxx, 0.0001*np.exp(-np.sqrt(2.0)*xxx), label="sqrt 2.0" )
plt.plot( xxx, 0.0001*np.exp(-2.0*xxx), label="2.0" )

plt.legend()
plt.yscale("log")
plt.ylim(1.0e-13, 1.0e0)
# Out:
# (1e-13, 1.0)

# %%
corrs_aa = np.full( (len(files[ninit*nt0s:imax]), Nt, 3), 0. )
corrs_33 = np.full( (len(files[ninit*nt0s:imax]), Nt, 3), 0. )

for ab in range(1,4):
    files_ = sorted(glob.glob(path+"/meson_"+str(ell)+"_"+str(em)+"_a"+str(ab)+"_h*_corr_v2.*"), key=sorted) # @@@ ill ordered
    files = np.array(files_) # [:nhits]

    corrs_=[]
    for file in natsorted(files)[ninit*nt0s:imax]:
#     for file in natsorted(files)[170:]:
        corr = np.loadtxt( file )
        corrs_.append( corr )

    corrs = np.array(corrs_)
    
    corrs_aa += corrs
    if ab==3:
        corrs_33 += corrs

plt.plot( np.mean(corrs_aa, axis=1).T[1] )
plt.plot( np.mean(corrs_33, axis=1).T[1] )

jk_aa = Jackknife( corrs_aa.shape[0], binsize )
jk_33 = Jackknife( corrs_33.shape[0], binsize )

jk_aa.set( take_real, corrs_aa )
jk_33.set( take_real, corrs_33 )
# jk.set( take_imag, corrs )
jk_aa.do_it()
jk_33.do_it()

# %%
# Nf=6

# gsq="4.000000"
gsq="8.000000"
# gsq="2.800000"
# gsq="0.500000"

# gsq="1.000000"
# gsq="0.500000"
# gsq="0.100000"To

# nu0="2.000000"
# nu0="1.500000"
nu0="1.000000"

nu1="2.750000" # "1.000000"
# nu1="2.000000"


at="0.200000"
Nt=128
L=1

at="0.200000"

# %%
# label="data_at"+str(at)+"nu0"+str(nu0)+"nu1"+str(nu1)+"nt"+str(Nt)+"L"+str(L)
# label="data_at"+str(at)+"nu0"+str(nu0)+"nu1"+str(nu1)+"nt"+str(Nt)+"L"+str(L)


# label="data_Nf"+str(Nf)+"_gsq"+str(gsq)+"at"+str(at)+"nu0"+str(nu0)+"nt"+str(Nt)+"L"+str(L)

label="data_gsq"+str(gsq)+"at"+str(at)+"nu1"+str(nu1)+"nt"+str(Nt)+"L"+str(L)

# %%
label
# Out:
# 'data_gsq8.000000at0.200000nu12.750000nt128L1'

# %%
path = dir1+label
path
# Out:
# '/mnt/baracuda_14/qed3/qed3/src/both_3d/data_gsq8.000000at0.200000nu12.750000nt128L1'

# %%
binsize=1

# %%
ell=0
em=0
nhits = 1

# %%
# jks33_=[]

ninit=20
nt0s=1
imax=503

corrs_aa = np.full( (nhits, Nt, 3), 0. )
corrs_33 = np.full( (nhits, Nt, 3), 0. )

for ab in range(1,4):
    files_ = sorted(glob.glob(path+"/meson_"+str(ell)+"_"+str(em)+"_a"+str(ab)+"_h*_corr_v2.*"), key=sorted) # @@@ ill ordered
    files = np.array(files_) # [:nhits]

corrs_aa = np.full( (len(files[ninit*nt0s:imax]), Nt, 3), 0. )
corrs_33 = np.full( (len(files[ninit*nt0s:imax]), Nt, 3), 0. )

for ab in range(1,4):
    files_ = sorted(glob.glob(path+"/meson_"+str(ell)+"_"+str(em)+"_a"+str(ab)+"_h*_corr_v2.*"), key=sorted) # @@@ ill ordered
    files = np.array(files_) # [:nhits]

    corrs_=[]
    for file in natsorted(files)[ninit*nt0s:imax]:
#     for file in natsorted(files)[170:]:
        corr = np.loadtxt( file )
        corrs_.append( corr )

    corrs = np.array(corrs_)
    
    corrs_aa += corrs
    if ab==3:
        corrs_33 += corrs

plt.plot( np.mean(corrs_aa, axis=1).T[1] )
plt.plot( np.mean(corrs_33, axis=1).T[1] )

jk_aa = Jackknife( corrs_aa.shape[0], binsize )
jk_33 = Jackknife( corrs_33.shape[0], binsize )

jk_aa.set( take_real, corrs_aa )
jk_33.set( take_real, corrs_33 )
# jk.set( take_imag, corrs )
jk_aa.do_it()
jk_33.do_it()
    
# jks_.append([ab, jk.mean(),jk.err()])
    
# plt.ylim(0.0045, 0.0046)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 29
#      25     corrs_.append( corr )
#      27 corrs = np.array(corrs_)
# ---> 29 corrs_aa += corrs
#      30 if ab==3:
#      31     corrs_33 += corrs
#
# ValueError: operands could not be broadcast together with shapes (0,128,3) (0,) (0,128,3)

# %%
# desc="at"+str(at)+"_nu0"+str(nu0)+"_nu1"+str(nu1)
desc="Nf"+str(Nf)+"_gsq"+str(gsq)+"_at"+str(at)+"_nu0"+str(nu0)+"_nu1"+str(nu1)

# %%
xxx = float(at) * np.arange(Nt)

# %%
plt.errorbar( xxx, jk_33.mean(), jk_33.err(), label="33" )
plt.errorbar( xxx, -jk_aa.mean(), jk_aa.err(), label="m_aa" )
plt.errorbar( xxx, jk_aa.mean(), jk_aa.err(), label="aa" )

# plt.plot( xxx, 0.01*np.exp(-2.0*xxx) )
# plt.plot( xxx, 0.01*np.exp(-3.0*xxx) )

plt.yscale("log")
plt.ylim(1.0e-13, 1.0e0)

plt.legend()

plt.savefig(desc+"JA_corr.pdf")

# %%
jk_ell1em1_33 = jk_33

# %%
jk_ell1em0_33 = jk_33

# %%
jk_ell0em0_aa = jk_aa

# %%
plt.errorbar( xxx, jk_ell1em1_33.mean(), jk_ell1em1_33.err(), label="11_33" )
plt.errorbar( xxx, jk_ell1em0_33.mean(), jk_ell1em0_33.err(), label="10_33" )
plt.errorbar( xxx, -jk_ell0em0_aa.mean()/3.0, jk_ell0em0_aa.err()/3.0, label="00_aa" )

# plt.plot( xxx, 0.01*np.exp(-2.0*xxx) )
# plt.plot( xxx, 0.01*np.exp(-3.0*xxx) )

plt.yscale("log")
plt.ylim(1.0e-13, 1.0e0)

plt.legend()
plt.savefig(desc+"JA_corr_factor_check.pdf")

# %%
plt.errorbar( xxx, -jk_ell1em1_33.mean()/jk_ell0em0_aa.mean(), jk_ell1em0_33.err(), label="10_33" )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar( xxx, -jk_ell1em0_33.mean()/jk_ell0em0_aa.mean(), jk_ell1em0_33.err(), label="10_33" )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
jks_[0][1][47]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 jks_[0][1][47]
#
# NameError: name 'jks_' is not defined

# %%
# 1.3157697610054052e-09

# %%
-jks_[0][1][47]
# Out:
# 6.88946592273352e-10

# %%
# plt.errorbar(np.arange(1,Nt/2)*float(at), jks_[0][1], jks_[0][2], capsize=2.0, label='$\\Gamma=1$')

plt.errorbar(np.arange(Nt)*float(at), np.abs(jks_[0][1])+jks_[0][1][47], jks_[0][2], capsize=2.0, label='$\\Gamma=1$')
# plt.errorbar(np.arange(Nt)*float(at), jks_[1][1], jks_[1][2], capsize=2.0, label='$\\Gamma=\\sigma_1$')
# plt.errorbar(np.arange(Nt)*float(at), jks_[2][1], jks_[2][2], capsize=2.0, label='$\\Gamma=\\sigma_2$')
# plt.errorbar(np.arange(Nt)*float(at), jks_[3][1], jks_[3][2], capsize=2.0, label='$\\Gamma=\\sigma_3$')
plt.yscale("log")
plt.title(desc)

# plt.plot( np.arange(Nt)*float(at), free.T[1], label='free', ls='dashed' )

x = np.arange(1,Nt/2)*float(at)
# plt.plot(x, 0.008*np.exp(-2.4*x), label="exp(-2.6x)")
plt.plot(x, 0.02*np.exp(-2.0*x), label="exp(-2.0x)")

# plt.ylim(1.0e-4, 1.0e-5)
plt.legend()

plt.savefig( desc+"_wall.pdf", bbox_inches="tight" )

# %%
# fitm = int(5.0 / 0.2)
# fitM = int(8.0 / 0.2)

fitm = int(1.2 / 0.2)
fitM = int(5.0 / 0.2)


def meff( cor ):
    avg = (cor[1:int(Nt/2)] + np.flip(cor[int(Nt/2)+1:]))/2
    tmp = np.arccosh(avg/cor[int(Nt/2)])
    return (-tmp[1:]+tmp[:-1])/float(at)
    # return -np.log(avg[1:]/avg[:-1])/float(at)

xx = np.arange(1,int(Nt/2)-1)*float(at)

# def fitter( x, m1, m2, A ):
#     return np.full( x.shape[0], m1)

def fitter( x, m1, m2, A ):
    return m1 + A * np.exp(-m2*x)

# def meff( cor ):
#     tmp = np.arccosh(l1_1/l1_1[int(Nt/2)])
#     return (-tmp[1:]+tmp[:-1])/float(at)

# %%
jk_M = []

for l1_1 in jk.jack_avg:
    jk_M.append( meff(l1_1) )

# %%
jk_meff = Jackknife( len(jk_M), 1 )
jk_meff.set( jack_avg, jk_M )
jk_meff.do_it()

# %%
jk_mass=[]

for l1_1 in jk.jack_avg:
    yy = meff(l1_1)

    opt = sp.optimize.curve_fit( fitter, xx[fitm:fitM], yy[fitm:fitM],
                                 sigma=jk_meff.err()[fitm:fitM],
                           p0=(np.sqrt(2.0), 2, 0.01 ), 
                           full_output=True, absolute_sigma=True )

    jk_mass.append( opt[0] )
# Out:
# /tmp/ipykernel_5721/3226063778.py:20: RuntimeWarning: overflow encountered in exp
#   return m1 + A * np.exp(-m2*x)

# %%
jk_fit = Jackknife( len(jk_mass), binsize )
jk_fit.set( jack_avg, jk_mass )
jk_fit.do_it()

# %%
jk_fit.mean()
# Out:
# array([1.44291323, 0.85361311, 3.73484802])

# %%
plt.errorbar( xx, jk_meff.mean(), jk_meff.err(), label=str(fitm*float(at))+":"+str(fitM*float(at)) )

plt.plot( xx, fitter(xx, jk_fit.mean()[0], jk_fit.mean()[1], jk_fit.mean()[2] ) )

plt.ylim(0.0,5.0)

plt.title(format_print_w_exact(2.0+ell, jk_fit.mean()[0], jk_fit.err()[0] ))
plt.legend()

plt.savefig( desc+"_fit"+str(ell)+str(em)+".pdf", bbox_inches="tight" )

# %%
opt
# Out:
# (array([1.81653499, 1.12126363, 3.94230431]),
#  array([[0.00497287, 0.01252909, 0.04488511],
#         [0.01252909, 0.04497264, 0.19114834],
#         [0.04488511, 0.19114834, 0.87826923]]),
#  {'fvec': array([-0.75976354,  0.6890516 ,  0.44451578, -0.01989423, -0.6149857 ,
#          -0.01525778,  0.20090733, -0.75311796, -0.46867176,  1.02355405,
#          -0.95610251,  0.91122916, -0.17313256, -1.17578566,  0.255932  ,
#           0.70738534,  0.41310475,  0.52647795, -0.43987899, -0.01795451]),
#   'nfev': 82,
#   'fjac': array([[-4.88712673e+01,  4.11033420e-01,  4.07269378e-01,
#            3.29931993e-01,  2.83724210e-01,  2.24662903e-01,
#            2.18697340e-01,  1.75279930e-01,  2.19231666e-01,
#            1.44573860e-01,  1.93144323e-01,  1.42856992e-01,
#            1.50446056e-01,  1.06569119e-01,  1.26167998e-01,
#            1.72187242e-01,  1.12711763e-01,  9.98113299e-02,
#            9.02063280e-02,  8.60139181e-02],
#          [ 4.00195622e+01,  1.72241931e+01,  1.50142399e-01,
#            2.24648046e-02, -6.57728771e-02, -1.16646347e-01,
#           -1.72114531e-01, -1.80796460e-01, -2.74300546e-01,
#           -2.09087419e-01, -3.12439247e-01, -2.52436135e-01,
#           -2.85303086e-01, -2.13955087e-01, -2.65323228e-01,
#           -3.76080543e-01, -2.53948222e-01, -2.30704281e-01,
#           -2.12941101e-01, -2.06603825e-01],
#          [-6.21230984e+00, -3.74870917e+00,  1.06705343e+00,
#            4.79443691e-01,  4.61875401e-01,  3.59638457e-01,
#            3.16207984e-01,  2.13067376e-01,  2.07494118e-01,
#            9.59099453e-02,  7.39463177e-02,  1.64632263e-02,
#           -2.00564908e-02, -3.83297690e-02, -7.09968781e-02,
#           -1.27880762e-01, -1.01513981e-01, -1.03623558e-01,
#           -1.04381755e-01, -1.08327795e-01]]),
#   'ipvt': array([0, 1, 2], dtype=int32),
#   'qtf': array([ 1.35274335e-05, -4.32232513e-05, -1.75842186e-04])},
#  'Both actual and predicted relative reductions in the sum of squares\n  are at most 0.000000',
#  1)

# %%
results.append( [nu0, yy] )

# %%
desc="Nf"+str(Nf)+"_gsq"+str(gsq)+"_at"+str(at)

# %%
for result in results:
    plt.plot( result[1], label='nu0='+result[0] )

plt.hlines(1.0, 0,40)
plt.legend()

plt.ylim(0.5, 5.5)
plt.savefig( desc+"_meff_wall.pdf", bbox_inches="tight" )

# %%
for result in results:
    plt.plot( result[1], label='nu0='+result[0] )

plt.hlines(1.0, 0,40)
plt.legend()

plt.savefig( desc+"_meff_wall.pdf", bbox_inches="tight" )

# %%
results
# Out:
# [['0.800000',
#   array([14.31135073,  7.32799627,  5.19935481,  4.15273213,  3.53193435,
#           3.11899384,  2.82506991,  2.60155771,  2.42719058,  2.26364864,
#           2.17139397,  2.08068865,  1.97974129,  1.91857776,  1.84572363,
#           1.80940649,  1.73934755,  1.66170358,  1.61394484,  1.63033047,
#           1.5303927 ,  1.44781997,  1.41516604,  1.39760592,  1.39188435,
#           1.39350314,  1.36891993,  1.38751764,  1.39664116,  1.29992616,
#           1.27215703,  1.24686085,  1.20057877,  1.22311721,  1.19078713,
#           1.18530826,  1.07578871,  1.1294769 ,  1.19696926,  1.1534396 ,
#           1.15087212,  1.15994308,  1.05108651,  0.88791309,  0.66120695,
#           0.40940391,  0.24658396,  0.1207837 , -0.110848  , -0.40858376,
#          -0.55914197, -0.79508303, -0.83566636, -0.87745112, -0.94929671,
#          -1.05437737, -1.09733747, -1.14852648, -1.13609956, -1.1806056 ,
#          -1.15748134, -1.25680998, -1.25381433, -1.3113634 , -1.30914686,
#          -1.29778202, -1.34024331, -1.31808356, -1.35493548, -1.3021082 ,
#          -1.37020927, -1.4281184 , -1.43053178, -1.47937744, -1.47029616,
#          -1.53630654, -1.56725753, -1.63429075, -1.69771774, -1.72430661,
#          -1.79592405, -1.81385573, -1.87255195, -1.94563611, -2.03889707,
#          -2.14320381, -2.30383011, -2.42815748, -2.58945947, -2.82596726,
#          -3.1146066 , -3.53953475, -4.1572706 , -5.19449163, -7.33293161])],
#  ['1.000000',
#   array([14.59784411,  7.63104723,  5.47362021,  4.4050004 ,  3.76158577,
#           3.36817139,  3.08064983,  2.85839378,  2.65082372,  2.50570269,
#           2.381972  ,  2.25421639,  2.17126549,  2.12348338,  1.95167035,
#           1.93295199,  1.83110388,  1.75750638,  1.72523986,  1.60478466,
#           1.63845091,  1.49431124,  1.53595274,  1.66663306,  1.37428863,
#           1.42258774,  1.48082798,  1.44254733,  1.44038733,  1.4149295 ,
#           1.45913621,  1.34010629,  1.30243308,  1.26590141,  1.23584735,
#           1.17495068,  1.1313122 ,  0.95924969,  1.02648707,  1.15318661,
#           1.06549222,  1.01996142,  1.04841008,  0.84533762,  0.73096247,
#           0.40526102,  0.32804675,  0.1526741 , -0.15705432, -0.47588934,
#          -0.57010754, -0.77820209, -0.73402179, -0.75331521, -0.83600866,
#          -0.97672839, -1.0950957 , -1.07594771, -1.31744115, -1.20034064,
#          -1.23769496, -1.30109307, -1.33585797, -1.39075034, -1.27793681,
#          -1.39624643, -1.31624892, -1.39739571, -1.41905491, -1.44950823,
#          -1.38400233, -1.55642657, -1.61180913, -1.62643952, -1.61170816,
#          -1.62672913, -1.65558179, -1.73235869, -1.72503475, -1.80107716,
#          -1.85872869, -1.97765243, -2.02859595, -2.11202243, -2.21335202,
#          -2.35227003, -2.5281168 , -2.64633438, -2.81384891, -3.0466145 ,
#          -3.36303179, -3.79470158, -4.39680392, -5.45758401, -7.6112514 ])],
#  ['1.200000',
#   array([14.85812536,  7.87516707,  5.71149029,  4.65469613,  3.98489425,
#           3.5488556 ,  3.24524156,  3.00514121,  2.84847862,  2.64572187,
#           2.48321906,  2.39161391,  2.24350285,  2.09293811,  2.04147384,
#           1.98737297,  1.8753578 ,  1.79145234,  1.75937079,  1.6764659 ,
#           1.60260498,  1.50521942,  1.61003698,  1.67033591,  1.49314576,
#           1.40513505,  1.34066957,  1.19687838,  1.25344205,  1.3112633 ,
#           1.38996435,  1.27956802,  1.22732309,  1.32983288,  1.38628225,
#           1.10053559,  1.17005298,  1.20876787,  1.33627613,  1.29585762,
#           1.16746671,  1.24988322,  0.91262079,  0.73933308,  0.74490401,
#           0.43027469,  0.20598171, -0.11643799, -0.2097674 , -0.33111381,
#          -0.61065033, -0.8591877 , -1.08712126, -1.1817908 , -1.03539063,
#          -1.08131034, -1.01744638, -1.21873514, -1.31768313, -1.22646539,
#          -0.98204188, -1.13167355, -1.26306256, -1.25276992, -1.28654895,
#          -1.3134412 , -1.27537331, -1.30803981, -1.40024526, -1.50311933,
#          -1.49312478, -1.61943373, -1.45485633, -1.51085274, -1.47066922,
#          -1.45741747, -1.58643373, -1.67828375, -1.855647  , -1.86594877,
#          -1.90843083, -2.00200685, -2.12631675, -2.21771154, -2.22911086,
#          -2.4388558 , -2.6727869 , -2.84026272, -2.98377835, -3.23402935,
#          -3.56306651, -3.99136127, -4.64099688, -5.70943383, -7.86750709])]]

# %%
# 1 0.138394
# 2 0.073868
# 4 2.994744726728921e-01

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica",
    'font.size'  : 20
})

# %%
def f(t, nmax, T):
    res = 0.0
    for n in range(1,nmax):
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*t )
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*(T-t) )
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*(t+T) )
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*(2*T-t) )
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*(t+2*T) )
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*(3*T-t) )
    return res/(8.0*np.pi)

# %%
Nt=96

# %%
gsq=0.50000
beta=1.0/gsq

# %%
# gsq=2.00000
# beta=1.0/gsq

# key_1='gsq2.000000at0.500000nt24L1__corr'
# key_2='gsq2.000000at0.500000nt24L2__corr'
# # key_4='gsq0.500000at0.375000nt32L4_'

# l1_1 = np.loadtxt("corr_"+key_1+".dat")
# l1_2 = np.loadtxt("corr_"+key_2+".dat")
# # l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
# plt.yscale("log")

# xx=np.arange(24)*0.5000
# plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
# plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
# # plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

# xx=np.linspace(0, 12, 5000)

# yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
# plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

# yy= (1.0/beta)*f(xx, 2, 12) # *fixme*
# plt.plot( xx, yy, ls='dashed', c='red', label='exact' )

# plt.xlabel("$t$")
# plt.title("$1/g^2 = 20, a_t=0.05, N_t=96$")

# plt.xlim(0, 12)
# plt.ylim(1.0e-5, 1.0e2)
# plt.legend()

# # plt.savefig("jtjt.pdf")

# %%
key_1='gsq0.500000at0.500000nt24L1__corr'
key_2='gsq0.500000at0.500000nt24L2__corr'
key_4='gsq0.500000at0.500000nt24L4__corr'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
l1_4 = np.loadtxt("corr_"+key_4+".dat")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 l1_1 = np.loadtxt("corr_"+key_1+".dat")
#       6 l1_2 = np.loadtxt("corr_"+key_2+".dat")
# ----> 7 l1_4 = np.loadtxt("corr_"+key_4+".dat")
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/numpy/lib/npyio.py:1356, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1353 if isinstance(delimiter, bytes):
#    1354     delimiter = delimiter.decode('latin1')
# -> 1356 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1357             converters=converters, skiplines=skiprows, usecols=usecols,
#    1358             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1359             max_rows=max_rows, quote=quotechar)
#    1361 return arr
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/numpy/lib/npyio.py:975, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     973     fname = os.fspath(fname)
#     974 if isinstance(fname, str):
# --> 975     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     976     if encoding is None:
#     977         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: corr_gsq0.500000at0.500000nt24L4__corr.dat not found.

# %%
plt.yscale("log")

xx=np.arange(24)*0.5000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
# plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 12, 5000)

yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

# yy= (1.0/beta)*f(xx, 2, 12) # *fixme*
# plt.plot( xx, yy, ls='dashed', c='red', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 2, a_t=0.5, N_t=24$")

plt.xlim(0, 12)
plt.ylim(1.0e-5, 1.0e2)
plt.legend()

plt.savefig("jtjt_Nt24.pdf")

# %%
key_1='gsq0.500000at0.500000nt24L1__meff'
key_2='gsq0.500000at0.500000nt24L2__meff'
# key_4='gsq0.500000at0.375000nt32L4_'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
# l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
xx=np.arange(24)*0.5000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1] )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1] )
plt.hlines( np.sqrt(2.0), 0, 6, ls='dashed' )
plt.xlim(0,6)
plt.ylim(-2,7)
# Out:
# (-2.0, 7.0)

# %%
key_1='gsq0.500000at0.375000nt32L1__corr'
key_2='gsq0.500000at0.375000nt32L2__corr'
# key_4='gsq0.500000at0.375000nt32L4_'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
# l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
plt.yscale("log")

xx=np.arange(32)*0.375000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
# plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 12, 5000)

yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

# yy= (1.0/beta)*f(xx, 2, 12) # *fixme*
# plt.plot( xx, yy, ls='dashed', c='red', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 2, a_t=0.375, N_t=32$")

plt.xlim(0, 12)
plt.ylim(1.0e-5, 1.0e2)
plt.legend()

plt.savefig("jtjt_Nt32.pdf")

# %%
key_1='gsq0.500000at0.375000nt32L1__meff'
key_2='gsq0.500000at0.375000nt32L2__meff'
# key_4='gsq0.500000at0.375000nt32L4_'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
# l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
xx=np.arange(32)*0.375000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1] )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1] )
plt.hlines( np.sqrt(2.0), 0, 6, ls='dashed' )
plt.xlim(0,6)
plt.ylim(-2,7)
# Out:
# (-2.0, 7.0)

# %%
key_1='gsq0.500000at0.250000nt48L1__corr'
key_2='gsq0.500000at0.250000nt48L2__corr'
key_4='gsq0.500000at0.250000nt48L4__corr'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
binsize=100

# %%
plt.yscale("log")

xx=np.arange(48)*0.25
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 12, 5000)

yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 20, a_t=0.05, N_t=96$")

plt.xlim(0, 12)
plt.ylim(1.0e-5, 1.0e2)
plt.legend()

# plt.savefig("jtjt.pdf")

# %%
l1_4
# Out:
# array([[ 2.58567e+01,  1.34919e+00],
#        [ 3.08479e+00,  1.60966e-01],
#        [ 5.51226e-01,  2.87768e-02],
#        [ 1.51047e-01,  7.93309e-03],
#        [ 5.93289e-02,  3.22455e-03],
#        [ 3.15004e-02,  2.00753e-03],
#        [ 1.63628e-02,  1.24101e-03],
#        [ 7.25426e-03,  1.02069e-03],
#        [ 3.06745e-03,  1.06143e-03],
#        [ 1.46954e-05,  8.76100e-04],
#        [-8.55911e-04,  1.00474e-03],
#        [ 1.69758e-04,  9.64366e-04],
#        [-3.48861e-04,  9.06459e-04],
#        [ 2.80285e-03,  9.75635e-04],
#        [ 3.59740e-03,  1.10333e-03],
#        [ 2.56943e-03,  9.23602e-04],
#        [ 2.84282e-03,  1.01567e-03],
#        [-1.56302e-04,  8.19089e-04],
#        [-9.99339e-04,  1.03418e-03],
#        [-4.02704e-03,  9.82837e-04],
#        [-3.54848e-03,  1.02323e-03],
#        [-2.90794e-04,  9.19606e-04],
#        [ 1.35805e-03,  8.99457e-04],
#        [ 8.94548e-04,  7.69531e-04],
#        [ 2.73321e-03,  1.39947e-03],
#        [ 8.94548e-04,  7.69531e-04],
#        [ 1.35805e-03,  8.99457e-04],
#        [-2.90794e-04,  9.19606e-04],
#        [-3.54848e-03,  1.02323e-03],
#        [-4.02704e-03,  9.82837e-04],
#        [-9.99339e-04,  1.03418e-03],
#        [-1.56302e-04,  8.19089e-04],
#        [ 2.84282e-03,  1.01567e-03],
#        [ 2.56943e-03,  9.23602e-04],
#        [ 3.59740e-03,  1.10333e-03],
#        [ 2.80285e-03,  9.75635e-04],
#        [-3.48861e-04,  9.06459e-04],
#        [ 1.69758e-04,  9.64366e-04],
#        [-8.55911e-04,  1.00474e-03],
#        [ 1.46954e-05,  8.76100e-04],
#        [ 3.06745e-03,  1.06143e-03],
#        [ 7.25426e-03,  1.02069e-03],
#        [ 1.63628e-02,  1.24101e-03],
#        [ 3.15004e-02,  2.00753e-03],
#        [ 5.93289e-02,  3.22455e-03],
#        [ 1.51047e-01,  7.93309e-03],
#        [ 5.51226e-01,  2.87768e-02],
#        [ 3.08479e+00,  1.60966e-01]])

# %%
l1_4
# Out:
# array([[ 3.91890e+01,  1.04023e-01],
#        [ 4.67528e+00,  1.23822e-02],
#        [ 8.35318e-01,  2.77511e-03],
#        [ 2.29001e-01,  1.68260e-03],
#        [ 8.98009e-02,  1.45274e-03],
#        [ 4.78226e-02,  1.99381e-03],
#        [ 2.50659e-02,  1.44156e-03],
#        [ 1.11009e-02,  1.59928e-03],
#        [ 4.57388e-03,  1.69327e-03],
#        [-2.16450e-04,  1.35749e-03],
#        [-1.29176e-03,  1.74603e-03],
#        [ 4.26626e-04,  1.58079e-03],
#        [-5.45515e-04,  1.48398e-03],
#        [ 4.18315e-03,  1.56814e-03],
#        [ 5.55080e-03,  1.69779e-03],
#        [ 3.83686e-03,  1.51308e-03],
#        [ 4.38214e-03,  1.70357e-03],
#        [-4.12958e-04,  1.30468e-03],
#        [-1.83008e-03,  1.75276e-03],
#        [-5.94236e-03,  1.55223e-03],
#        [-5.51766e-03,  1.61519e-03],
#        [-2.71268e-04,  1.49109e-03],
#        [ 2.21970e-03,  1.45413e-03],
#        [ 1.09788e-03,  1.14711e-03],
#        [ 4.38789e-03,  2.14837e-03],
#        [ 1.09788e-03,  1.14711e-03],
#        [ 2.21970e-03,  1.45413e-03],
#        [-2.71268e-04,  1.49109e-03],
#        [-5.51766e-03,  1.61519e-03],
#        [-5.94236e-03,  1.55223e-03],
#        [-1.83008e-03,  1.75276e-03],
#        [-4.12958e-04,  1.30468e-03],
#        [ 4.38214e-03,  1.70357e-03],
#        [ 3.83686e-03,  1.51308e-03],
#        [ 5.55080e-03,  1.69779e-03],
#        [ 4.18315e-03,  1.56814e-03],
#        [-5.45515e-04,  1.48398e-03],
#        [ 4.26626e-04,  1.58079e-03],
#        [-1.29176e-03,  1.74603e-03],
#        [-2.16450e-04,  1.35749e-03],
#        [ 4.57388e-03,  1.69327e-03],
#        [ 1.11009e-02,  1.59928e-03],
#        [ 2.50659e-02,  1.44156e-03],
#        [ 4.78226e-02,  1.99381e-03],
#        [ 8.98009e-02,  1.45274e-03],
#        [ 2.29001e-01,  1.68260e-03],
#        [ 8.35318e-01,  2.77511e-03],
#        [ 4.67528e+00,  1.23822e-02]])

# %%
plt.yscale("log")

xx=np.arange(48)*0.25
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 12, 5000)

yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 20, a_t=0.05, N_t=96$")

plt.xlim(0, 12)
plt.ylim(1.0e-5, 1.0e2)
plt.legend()

# plt.savefig("jtjt.pdf")

# %%
binsize=2000

# %%
plt.yscale("log")

xx=np.arange(48)*0.25
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 12, 5000)

yy= (1.0/beta)*f(xx, 4000, 12) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 20, a_t=0.05, N_t=96$")

plt.xlim(0, 12)
plt.ylim(1.0e-5, 1.0e2)
plt.legend()

# plt.savefig("jtjt.pdf")

# %%
key_1='gsq0.500000at0.250000nt48L1__meff'
key_2='gsq0.500000at0.250000nt48L2__meff'
# key_4='gsq0.500000at0.375000nt32L4_'

l1_1 = np.loadtxt("corr_"+key_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2+".dat")
# l1_4 = np.loadtxt("corr_"+key_4+".dat")

# %%
xx=np.arange(48)*0.25000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1] )
plt.errorbar( xx, l1_2.T[0], l1_2.T[1] )
plt.hlines( np.sqrt(2.0), 0, 6, ls='dashed' )
plt.xlim(0,6)
plt.ylim(-2,7)
# Out:
# (-2.0, 7.0)

# %%
at=0.25

# %%
meff = -np.log( l1_1.T[0][1:]/l1_1.T[0][:-1] )

plt.plot( meff[:24]/at )
plt.hlines( np.sqrt(2.0), 0, 24, ls='dashed' )
# Out:
# /scratch/354095.1.ood/ipykernel_2309507/2497384176.py:1: RuntimeWarning: divide by zero encountered in divide
#   meff = -np.log( l1_1.T[0][1:]/l1_1.T[0][:-1] )
# /scratch/354095.1.ood/ipykernel_2309507/2497384176.py:1: RuntimeWarning: invalid value encountered in log
#   meff = -np.log( l1_1.T[0][1:]/l1_1.T[0][:-1] )

# %%
meff = -np.log( l1_2.T[0][1:]/l1_2.T[0][:-1] )

plt.plot( meff[:24]/at )
plt.hlines( np.sqrt(2.0), 0, 24, ls='dashed' )
# Out:
# /scratch/354095.1.ood/ipykernel_2309507/2068367678.py:1: RuntimeWarning: divide by zero encountered in divide
#   meff = -np.log( l1_2.T[0][1:]/l1_2.T[0][:-1] )
# /scratch/354095.1.ood/ipykernel_2309507/2068367678.py:1: RuntimeWarning: invalid value encountered in log
#   meff = -np.log( l1_2.T[0][1:]/l1_2.T[0][:-1] )

# %%
96
# Out:
# 96

# %%
at=0.050000
beta=20

key_2_1='gsq0.050000at0.100000nt48L2_'
key_2_2='gsq0.050000at0.075000nt64L2_'
key_2_3='gsq0.050000at0.050000nt96L2_'

# %%
l1_1 = np.loadtxt("corr_"+key_2_1+".dat")
l1_2 = np.loadtxt("corr_"+key_2_2+".dat")
# l1_3 = np.loadtxt("corr_"+key_3+".dat")
l1_4 = np.loadtxt("corr_"+key_2_3+".dat")
# l2 = np.loadtxt("corr_"+key+"nt96L2_short.dat")
# l4 = np.loadtxt("corr_"+key+"nt96L4_short.dat")
# Out:
# /scratch/352694.1.ood/ipykernel_470825/2989030815.py:1: UserWarning: loadtxt: input contained no data: "corr_gsq0.050000at0.100000nt48L2_.dat"
#   l1_1 = np.loadtxt("corr_"+key_2_1+".dat")

# %%
plt.yscale("log")

xx=np.arange(48)*0.100000
plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
xx=np.arange(64)*0.075000
plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
xx=np.arange(96)*0.050000
plt.errorbar( xx, l1_4.T[0], l1_4.T[1], capsize=5, fmt='o-', label="$L=4$" )

xx=np.linspace(0, 4.8, 5000)

yy= (1.0/beta)*f(xx, 4000, 4.8) # *fixme*
plt.plot( xx, yy, ls='dashed', c='black', label='exact' )

plt.xlabel("$t$")
plt.title("$1/g^2 = 20, a_t=0.05, N_t=96$")

plt.xlim(0, 5)
plt.ylim(1.0e-4, 1.0e2)
plt.legend()

# plt.savefig("jtjt.pdf")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 plt.yscale("log")
#       3 xx=np.arange(48)*0.100000
# ----> 4 plt.errorbar( xx, l1_1.T[0], l1_1.T[1], capsize=5, fmt='x-', label="$L=1$" )
#       5 xx=np.arange(64)*0.075000
#       6 plt.errorbar( xx, l1_2.T[0], l1_2.T[1], capsize=5, fmt='v-', label="$L=2$" )
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
l1 = np.loadtxt("corr_beta5.000000at0.100000nt96L1.dat")
l2 = np.loadtxt("corr_beta5.000000at0.100000nt96L2.dat")
l4 = np.loadtxt("corr_beta5.000000at0.100000nt96L4.dat")

# %%
plt.yscale("log")

xx=np.arange(96)*0.2
plt.errorbar( xx, l1.T[0], l1.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l2.T[0], l2.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l4.T[0], l4.T[1], capsize=5, label="L=1" )


xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )

# yy= (1.0/300.0)*f(xx, 6)
# plt.plot( xx, yy )

# yy= (1.0/800.0)*f(xx, 11)
# plt.plot( xx, yy )

# yy= (1.0/800.0)*f(xx, 20)
# plt.plot( xx, yy )

yy= (1.0/5.0)*f(xx, 100)
plt.plot( xx, yy )


plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
l1 = np.loadtxt("corr_beta20.000000at0.100000nt96L1.dat")
l2 = np.loadtxt("corr_beta20.000000at0.100000nt96L2.dat")
l4 = np.loadtxt("corr_beta20.000000at0.100000nt96L4.dat")

# %%
plt.yscale("log")

xx=np.arange(96)*0.1
plt.errorbar( xx, l1.T[0], l1.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l2.T[0], l2.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l4.T[0], l4.T[1], capsize=5, label="L=1" )


xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )

# yy= (1.0/20.0)*f(xx, 6)
# plt.plot( xx, yy )

# yy= (1.0/20.0)*f(xx, 11)
# plt.plot( xx, yy )

# yy= (1.0/20.0)*f(xx, 20)
# plt.plot( xx, yy )

yy= (1.0/20.0)*f(xx, 100)
plt.plot( xx, yy )


plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
l1 = np.loadtxt("corr_beta50.000000at0.100000nt96L1.dat")
l2 = np.loadtxt("corr_beta50.000000at0.100000nt96L2.dat")
l4 = np.loadtxt("corr_beta50.000000at0.100000nt96L4.dat")

# %%
plt.yscale("log")

xx=np.arange(96)*0.1
plt.errorbar( xx, l1.T[0], l1.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l2.T[0], l2.T[1], capsize=5, label="L=2" )
plt.errorbar( xx, l4.T[0], l4.T[1], capsize=5, label="L=4" )


xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )

# yy= (1.0/50.0)*f(xx, 6)
# plt.plot( xx, yy )

# yy= (1.0/50.0)*f(xx, 11)
# plt.plot( xx, yy )

# yy= (1.0/50.0)*f(xx, 20)
# plt.plot( xx, yy )

plt.legend()
plt.xlabel("$t$")
plt.ylabel("$G(t)$")

yy= (1.0/50.0)*f(xx, 100)
plt.plot( xx, yy )


plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
l1 = np.loadtxt("corr_beta50.000000at0.100000nt96L1.dat")
l2 = np.loadtxt("corr_beta50.000000at0.100000nt96L2.dat")
l4 = np.loadtxt("corr_beta50.000000at0.100000nt96L4.dat")

# %%
plt.yscale("log")

xx=np.arange(96)*0.1
plt.errorbar( xx, l1.T[0], l1.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l2.T[0], l2.T[1], capsize=5, label="L=1" )
plt.errorbar( xx, l4.T[0], l4.T[1], capsize=5, label="L=1" )


xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )

yy= (1.0/50.0)*f(xx, 6)
plt.plot( xx, yy )

yy= (1.0/50.0)*f(xx, 11)
plt.plot( xx, yy )

yy= (1.0/50.0)*f(xx, 20)
plt.plot( xx, yy )

yy= (1.0/50.0)*f(xx, 100)
plt.plot( xx, yy )


plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
plt.yscale("log")

for res in res_list:
    Nt = res[1].shape[0]

    at = float(res[0].split("at")[1].split("nt")[0])
    xx=np.arange(int(Nt/2)) * at
    # xx=np.arange(Nt)
    yy=res[1][:int(Nt/2)]
    dy=res[2][:int(Nt/2)]

    plt.errorbar( xx, yy, dy, capsize=5, label=res[0] )

# xx=np.arange(Nt)
# yy= 0.07*np.exp( -np.sqrt(2.0) * xx / 8.0 )
# plt.plot( xx, yy )

xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )
yy= 0.0006*f(xx, 10)
plt.plot( xx, yy )



plt.legend()
plt.ylim( 1.0e-5, 1.0e0 )
# Out:
# (1e-05, 1.0)

# %%
l1
# Out:
# array([[ 1.36846e-01,  3.83936e-04],
#        [ 9.27521e-02,  3.81009e-04],
#        [ 6.35540e-02,  3.64255e-04],
#        [ 4.40706e-02,  3.48425e-04],
#        [ 3.09533e-02,  3.38998e-04],
#        [ 2.19969e-02,  3.24321e-04],
#        [ 1.58502e-02,  3.09281e-04],
#        [ 1.15498e-02,  2.98567e-04],
#        [ 8.51418e-03,  2.89944e-04],
#        [ 6.34319e-03,  2.94173e-04],
#        [ 4.79504e-03,  2.88819e-04],
#        [ 3.69040e-03,  2.76160e-04],
#        [ 2.90254e-03,  2.59906e-04],
#        [ 2.33086e-03,  2.29066e-04],
#        [ 1.94455e-03,  2.04223e-04],
#        [ 1.64468e-03,  1.87646e-04],
#        [ 1.36795e-03,  1.69771e-04],
#        [ 1.12203e-03,  1.53549e-04],
#        [ 8.84507e-04,  1.36835e-04],
#        [ 6.72361e-04,  1.29129e-04],
#        [ 5.04484e-04,  1.35618e-04],
#        [ 3.68713e-04,  1.38841e-04],
#        [ 2.98513e-04,  1.27299e-04],
#        [ 2.50617e-04,  9.39149e-05],
#        [ 2.07537e-04,  6.65377e-05],
#        [ 1.90550e-04,  7.68855e-05],
#        [ 1.60900e-04,  1.10202e-04],
#        [ 1.01938e-04,  1.32567e-04],
#        [-7.83564e-06,  1.44860e-04],
#        [-1.03191e-04,  1.55420e-04],
#        [-1.74206e-04,  1.67625e-04],
#        [-2.43386e-04,  1.83774e-04],
#        [-3.08516e-04,  2.03259e-04],
#        [-3.36378e-04,  2.12928e-04],
#        [-3.41344e-04,  2.23514e-04],
#        [-3.05445e-04,  2.43381e-04],
#        [-2.75989e-04,  2.69949e-04],
#        [-2.62679e-04,  2.89557e-04],
#        [-2.55033e-04,  2.96729e-04],
#        [-3.06409e-04,  2.96859e-04],
#        [-3.70004e-04,  2.96699e-04],
#        [-4.16392e-04,  3.06309e-04],
#        [-4.47746e-04,  3.18790e-04],
#        [-4.59786e-04,  3.31861e-04],
#        [-4.58253e-04,  3.45714e-04],
#        [-4.28897e-04,  3.54485e-04],
#        [-3.77848e-04,  3.69042e-04],
#        [-3.42981e-04,  3.87512e-04],
#        [-3.51779e-04,  3.93411e-04],
#        [-3.42981e-04,  3.87512e-04],
#        [-3.77848e-04,  3.69042e-04],
#        [-4.28897e-04,  3.54485e-04],
#        [-4.58253e-04,  3.45714e-04],
#        [-4.59786e-04,  3.31861e-04],
#        [-4.47746e-04,  3.18790e-04],
#        [-4.16392e-04,  3.06309e-04],
#        [-3.70004e-04,  2.96699e-04],
#        [-3.06409e-04,  2.96859e-04],
#        [-2.55033e-04,  2.96729e-04],
#        [-2.62679e-04,  2.89557e-04],
#        [-2.75989e-04,  2.69949e-04],
#        [-3.05445e-04,  2.43381e-04],
#        [-3.41344e-04,  2.23514e-04],
#        [-3.36378e-04,  2.12928e-04],
#        [-3.08516e-04,  2.03259e-04],
#        [-2.43386e-04,  1.83774e-04],
#        [-1.74206e-04,  1.67625e-04],
#        [-1.03191e-04,  1.55420e-04],
#        [-7.83564e-06,  1.44860e-04],
#        [ 1.01938e-04,  1.32567e-04],
#        [ 1.60900e-04,  1.10202e-04],
#        [ 1.90550e-04,  7.68855e-05],
#        [ 2.07537e-04,  6.65377e-05],
#        [ 2.50617e-04,  9.39149e-05],
#        [ 2.98513e-04,  1.27299e-04],
#        [ 3.68713e-04,  1.38841e-04],
#        [ 5.04484e-04,  1.35618e-04],
#        [ 6.72361e-04,  1.29129e-04],
#        [ 8.84507e-04,  1.36835e-04],
#        [ 1.12203e-03,  1.53549e-04],
#        [ 1.36795e-03,  1.69771e-04],
#        [ 1.64468e-03,  1.87646e-04],
#        [ 1.94455e-03,  2.04223e-04],
#        [ 2.33086e-03,  2.29066e-04],
#        [ 2.90254e-03,  2.59906e-04],
#        [ 3.69040e-03,  2.76160e-04],
#        [ 4.79504e-03,  2.88819e-04],
#        [ 6.34319e-03,  2.94173e-04],
#        [ 8.51418e-03,  2.89944e-04],
#        [ 1.15498e-02,  2.98567e-04],
#        [ 1.58502e-02,  3.09281e-04],
#        [ 2.19969e-02,  3.24321e-04],
#        [ 3.09533e-02,  3.38998e-04],
#        [ 4.40706e-02,  3.48425e-04],
#        [ 6.35540e-02,  3.64255e-04],
#        [ 9.27521e-02,  3.81009e-04]])

# %%
res_list=[]

binsize=10

# %%
path="./beta50.000000at0.138394nt32L1_v2/"
files_ = sorted(glob.glob(path+"plaq_ss_t_*.dat"), key=len)
files = np.array(files_)

data_=[]
for file in files:
    data_.append( np.loadtxt( file ) )
data = np.array( data_ )

Nt=data.shape[1]

jk = Jackknife( data.shape[0], binsize )
jk.set( simple_mean, data )
jk.do_it()

res_list.append( [path, jk.mean(), jk.err()] )

# %%
path="./beta50.000000at0.069197nt32L1_v2/"
files_ = sorted(glob.glob(path+"plaq_ss_t_*.dat"), key=len)
files = np.array(files_)

data_=[]
for file in files:
    data_.append( np.loadtxt( file ) )
data = np.array( data_ )

Nt=data.shape[1]

jk = Jackknife( data.shape[0], binsize )
jk.set( simple_mean, data )
jk.do_it()

res_list.append( [path, jk.mean(), jk.err()] )

# %%
path="./beta50.000000at0.036934nt32L2_v2/"
files_ = sorted(glob.glob(path+"plaq_ss_t_*.dat"), key=len)
files = np.array(files_)

data_=[]
for file in files:
    data_.append( np.loadtxt( file ) )
data = np.array( data_ )

Nt=data.shape[1]

jk = Jackknife( data.shape[0], binsize )
jk.set( simple_mean, data )
jk.do_it()

res_list.append( [path, jk.mean(), jk.err()] )

# %%
res_list
# Out:
# [['./beta50.000000at0.138394nt32L1_v2/',
#   array([0.05378207, 0.03163215, 0.0189523 , 0.01149634, 0.00708858,
#          0.00448384, 0.00284665, 0.00177947, 0.00118273, 0.00081948,
#          0.00053707, 0.00034221, 0.00030449, 0.00026111, 0.00019233,
#          0.00019217, 0.00022491, 0.00019217, 0.00019233, 0.00026111,
#          0.00030449, 0.00034221, 0.00053707, 0.00081948, 0.00118273,
#          0.00177947, 0.00284665, 0.00448384, 0.00708858, 0.01149634,
#          0.0189523 , 0.03163215]),
#   array([5.21833502e-05, 4.74696688e-05, 4.24059908e-05, 3.93463202e-05,
#          3.80315951e-05, 3.66643497e-05, 3.50076707e-05, 3.55485093e-05,
#          3.59880843e-05, 3.66644322e-05, 3.60388806e-05, 3.70653828e-05,
#          3.84997536e-05, 3.98424565e-05, 4.31942074e-05, 4.88073469e-05,
#          5.25850352e-05, 4.88073469e-05, 4.31942074e-05, 3.98424565e-05,
#          3.84997536e-05, 3.70653828e-05, 3.60388806e-05, 3.66644322e-05,
#          3.59880843e-05, 3.55485093e-05, 3.50076707e-05, 3.66643497e-05,
#          3.80315951e-05, 3.93463202e-05, 4.24059908e-05, 4.74696688e-05])],
#  ['./beta50.000000at0.069197nt32L1_v2/',
#   array([ 0.06046798,  0.0396448 ,  0.03025075,  0.02914686,  0.01559516,
#           0.01419492,  0.01666902,  0.00575328,  0.00754755,  0.00980632,
#           0.00033111,  0.00523781,  0.00746985, -0.00093351,  0.00507355,
#           0.00534131, -0.00236533,  0.00534131,  0.00507355, -0.00093351,
#           0.00746985,  0.00523781,  0.00033111,  0.00980632,  0.00754755,
#           0.00575328,  0.01666902,  0.01419492,  0.01559516,  0.02914686,
#           0.03025075,  0.0396448 ]),
#   array([1.24598357e-04, 7.35075561e-05, 7.44593569e-05, 7.91447583e-05,
#          9.16544067e-05, 5.72673947e-05, 1.05685591e-04, 6.90698291e-05,
#          5.32456859e-05, 6.72096295e-05, 1.09457097e-04, 5.65497901e-05,
#          8.91286117e-05, 8.13767850e-05, 7.38825556e-05, 7.43210280e-05,
#          1.29943951e-04, 7.43210280e-05, 7.38825556e-05, 8.13767850e-05,
#          8.91286117e-05, 5.65497901e-05, 1.09457097e-04, 6.72096295e-05,
#          5.32456859e-05, 6.90698291e-05, 1.05685591e-04, 5.72673947e-05,
#          9.16544067e-05, 7.91447583e-05, 7.44593569e-05, 7.35075561e-05])],
#  ['./beta50.000000at0.036934nt32L2_v2/',
#   array([ 0.51829747,  0.32540108,  0.27170997,  0.19631162,  0.13656231,
#           0.1331303 ,  0.0640394 ,  0.07887251,  0.05726132,  0.0205054 ,
#           0.06666602, -0.00149233,  0.04558212,  0.01115736,  0.01913383,
#           0.03780664, -0.0080417 ,  0.03780664,  0.01913383,  0.01115736,
#           0.04558212, -0.00149233,  0.06666602,  0.0205054 ,  0.05726132,
#           0.07887251,  0.0640394 ,  0.1331303 ,  0.13656231,  0.19631162,
#           0.27170997,  0.32540108]),
#   array([0.00123342, 0.00095865, 0.00063857, 0.00058488, 0.00052926,
#          0.00050317, 0.0004924 , 0.0004788 , 0.00059996, 0.00082841,
#          0.0010086 , 0.00086314, 0.00075546, 0.00074705, 0.00059739,
#          0.00054673, 0.00074235, 0.00054673, 0.00059739, 0.00074705,
#          0.00075546, 0.00086314, 0.0010086 , 0.00082841, 0.00059996,
#          0.0004788 , 0.0004924 , 0.00050317, 0.00052926, 0.00058488,
#          0.00063857, 0.00095865])]]

# %%
def f(t, nmax):
    res = 0.0
    for n in range(1,nmax):
        res += np.sqrt( n*(n+1.0) ) * (2.0*n+1.0) * np.exp( -np.sqrt( n*(n+1.0) )*t )
    return res

# %%
Nt
# Out:
# 32

# %%
plt.yscale("log")

for res in res_list:
    Nt = res[1].shape[0]

    at = float(res[0].split("at")[1].split("nt")[0])
    xx=np.arange(int(Nt/2)) * at
    # xx=np.arange(Nt)
    yy=res[1][:int(Nt/2)]
    dy=res[2][:int(Nt/2)]

    plt.errorbar( xx, yy, dy, capsize=5, label=res[0] )

# xx=np.arange(Nt)
# yy= 0.07*np.exp( -np.sqrt(2.0) * xx / 8.0 )
# plt.plot( xx, yy )

xx=np.linspace(0,3.0,50)
# yy= 0.02*np.exp( -np.sqrt(2.0) * xx * 2.4 )
yy= 0.0006*f(xx, 10)
plt.plot( xx, yy )



plt.legend()
plt.ylim( 1.0e-5, 1.0e0 )
# Out:
# (1e-05, 1.0)

# %%
50.0/8.0
# Out:
# 6.25
