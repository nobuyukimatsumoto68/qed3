# %%
import os
import numpy as np
import math
import matplotlib.pyplot as plt

import scipy as sp
import scipy.linalg
import scipy.optimize

import glob

from natsort import natsorted

import h5py

# # import lsqfit
# from lib import Jackknife
# from lib import simple_mean
# from lib import format_print

# plt.rcParams['figure.dpi'] = 300

# %%
class Jackknife:
    def __init__( self, len_data, binsize ):
        self.binsize = binsize
        self.nbins = math.floor( len_data/self.binsize )
        self.N = self.binsize * self.nbins
        self.jack_avg = []
        self.est = 0
        self.var_est = 0

    def set( self, func, list_of_data ):
        for i in range( self.nbins ):
            self.jack_avg.append( func( i, self.binsize, list_of_data ) )

    def do_it( self ):
        for i in range( 0, self.nbins ):
            self.est += self.jack_avg[i]
        self.est /= self.nbins

        for i in range( 0, self.nbins ):
            self.var_est += ( self.jack_avg[i] - self.est )**2
        self.var_est /= self.nbins
        self.var_est *= self.nbins -1

    def mean( self ):
        return self.est

    def var( self ):
        return self.var_est

    def err( self ):
        return np.sqrt(self.var_est)

def simple_mean(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    return np.mean(resmpld, axis=0)

def jack_avg(i, binsize, np_data):
    return np_data[i]

def take_abs(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    mean = np.mean(resmpld, axis=0)
    # mean = mean[1:int(Nt/2)] + np.flip( mean[int(Nt/2):Nt-1], axis=0 )

    return np.sqrt(mean.T[1]**2 + mean.T[2]**2)


def take_real(i, binsize, np_data):
    resmpld = np.delete(np_data, np.s_[i*binsize:(i+1)*binsize], axis=0)
    mean = np.mean(resmpld, axis=0)
    # mean = mean[1:int(Nt/2)] + np.flip( mean[int(Nt/2):Nt-1], axis=0 )
    return mean.T[1]


def format_print(cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'

def format_print_w_exact(exact, cen, err):
    for i in range(-50, 50):
        if 10**(-i+1)>=err>10**(-i):
            tmp=err*10**(i+1)
            return '{num:.{width}f}'.format(num=cen, width=i+1)+'('+str(round(tmp))+')'+': '+'{num:.{width}f}'.format(num=(exact-cen)/err, width=i+1)+' sigma'

# %%
at=0.2

# %%
pwd
# Out:
# '/mnt/barracuda22/qed3/qed3/src/both_3d'

# %%
# f = h5py.File("glue_ylm.hdf5", "r")
# print( f.keys() )
# # f1pt=f['1pt'][()]
# corrs=f['corr'][()][:2500]
# # f.create_dataset("corr", data=corrs, dtype='f' )
# # f.create_dataset("1pt", data=F1pts, dtype='f' )
# f.close()

# %%
Nf=2

# gsq="4.000000"
# gsq="2.800000"
gsq="2.000000"
# gsq="0.500000"

# gsq="1.000000"
# gsq="0.500000"
# gsq="0.100000"

# nu0="2.000000"
# nu0="1.500000"
nu0="1.000000"

nu1=nu0 # "1.000000"
# nu1="2.000000"


at="0.200000"
Nt=128
L=1

# %%
label="data_Nf"+str(Nf)+"_gsq"+str(gsq)+"at"+str(at)+"nu0"+str(nu0)+"nt"+str(Nt)+"L"+str(L)+"_msm"  # item 7: multi-flow output dir from glue2_msm_claude.cu
# label="data_gsq"+str(gsq)+"at"+str(at)+"nt"+str(Nt)+"L"+str(L)+"_msm"

# %%
dir1='/mnt/barracuda22/qed3/qed3/src/both_3d/'
path = dir1+label

# %%
path
# Out:
# '/mnt/barracuda22/qed3/qed3/src/both_3d/data_Nf2_gsq2.000000at0.200000nu01.000000nt128L1'

# %%
files_ = sorted(glob.glob(path+"/F_corr.*"), key=sorted) # @@@ ill ordered
files = np.array(files_)
iconfigs = [ int(fff.split('.')[-1]) for fff in natsorted(files)]
# iconfigs = [ int(fff.split('.')[-1]) for fff in natsorted(files)][170:]

corrs_=[]
F1pts_=[]
for i in iconfigs:
# for file in natsorted(files)[170:]:
    corr = np.loadtxt( path+"/F_corr."+str(i) )
    corr = (corr[1:int(Nt/2)] + np.flip( corr[int(Nt/2):Nt-1], axis=0 )).T
    # corr = (corr[1:int(Nt/2)]).T
    F1pt = np.loadtxt( path+"/F."+str(i) ) # [0]
    corrs_.append( corr )
    F1pts_.append( F1pt )

corrs = np.array(corrs_)
F1pts = np.array(F1pts_)

# plt.plot( np.mean(corrs, axis=1) )
# jks_.append([igam,jk.mean(),jk.err()])
    
# plt.ylim(0.0045, 0.0046)
plt.show()

# %%
np.sqrt( corr.shape[0] )
# Out:
# np.float64(16.0)

# %%
corrs.shape
# Out:
# (4440, 256, 63)

# %%
plt.plot( F1pts[0:] )
# Out:
# [<matplotlib.lines.Line2D at 0x730b1a91f250>,
#  <matplotlib.lines.Line2D at 0x730b1a91f390>,
#  <matplotlib.lines.Line2D at 0x730b1a91f4d0>,
#  <matplotlib.lines.Line2D at 0x730b1a91f610>,
#  <matplotlib.lines.Line2D at 0x730b1a91f750>,
#  <matplotlib.lines.Line2D at 0x730b1a91f890>,
#  <matplotlib.lines.Line2D at 0x730b1a91f9d0>,
#  <matplotlib.lines.Line2D at 0x730b1a91fb10>,
#  <matplotlib.lines.Line2D at 0x730b1a91fc50>,
#  <matplotlib.lines.Line2D at 0x730b1a91fd90>,
#  <matplotlib.lines.Line2D at 0x730b1a91fed0>,
#  <matplotlib.lines.Line2D at 0x730b1a934050>,
#  <matplotlib.lines.Line2D at 0x730b1a934190>,
#  <matplotlib.lines.Line2D at 0x730b1a9342d0>,
#  <matplotlib.lines.Line2D at 0x730b1a934410>,
#  <matplotlib.lines.Line2D at 0x730b1a934550>]

# %%
corrs.shape
# Out:
# (4440, 256, 63)

# %%
N_FLOW=3   # item 7: number of cumulative Wilson-flow checkpoints in glue2_msm_claude.cu
n_lm=16    # Ylm channels per flow time
nops=N_FLOW*n_lm   # 48; operator index op = iflow*n_lm + ilm
nops1=nops

nops2=8   # GEVP states kept (lightest); adjust as needed

# NOTE (pairs with item 5, SVD pruning): the N_FLOW cumulative-flow copies of a
# given Ylm channel are highly correlated, so the t0 metric matCA[trebase] can be
# near-singular -> inv(sqrtm(.)) noisy. If the GEVP is unstable, prune small
# singular directions of matCA[trebase] before inverting, or lower N_FLOW.

tcut=5
dt=1

trebase=1

# %%
# nops=6 # 9
# nops1=6

# nops2=4
# tcut=6
# dt=1

# trebase=1

# %%
desc="Nf"+str(Nf)+"_gsq"+str(gsq)+"_at"+str(at)+"_nu0"+str(nu0)

# %%
lm_set=np.array([
    [0,0],
    [1,-1],
    [1,0],
    [1,1],
    [2,-2],
    [2,-1],
    [2,0],
    [2,1],
    [2,2],
    [3,-3],
    [3,-2],
    [3,-1],
    [3,0],
    [3,1],
    [3,2],
    [3,3],
])
assert len(lm_set)==n_lm

# item 7: operators are N_FLOW cumulative-flow copies of the n_lm channels,
# op = iflow*n_lm + ilm (matches the obs index in glue2_msm_claude.cu).
opset=np.tile( lm_set, (N_FLOW,1) )
assert len(opset)==nops

# %%
len(opset)
# Out:
# 16

# %%
def get_II( irow ):
    return np.array([int(np.floor(irow/nops)), irow%nops ])

def get_lmlm( irow ):
    i1, i2 = get_II(irow)
    return np.array( [opset[i1], opset[i2]])

# %%
def vacuum_sub( conn, i, binsize ):
    # item 1: connected glueball correlator C_ij = <O_i O_j> - <O_i><O_j>.
    # Subtract the disconnected (vacuum) piece from the SAME jackknife sample,
    # i.e. delete the same bin from F1pts. Only the l=0 x l=0 block is materially
    # affected; the l>=1 1-pt averages vanish by rotational symmetry.
    # Layout: kron index i*nops+j matches the F_corr column order written by
    # glue2_msm_claude.cu (and F.k by glue2_msm has both F and F_corr /Nt-normalized
    # after the item-2 fix, so the two live on the same <..> scale).
    f1 = np.delete( F1pts, np.s_[i*binsize:(i+1)*binsize], axis=0 )
    mean1pt = np.mean( f1, axis=0 )
    prod1pt = np.kron( mean1pt, mean1pt )
    return conn - prod1pt[:, None]

# %%
jk = Jackknife( corrs.shape[0], 100 )
jk.set( simple_mean, corrs )
jk.do_it()

# %%
corrs.shape
# Out:
# (4440, 256, 63)

# %%
plt.plot( np.mean( corrs, axis=0 )[0], label=str(get_lmlm( 0 ).flatten()) )
plt.plot( np.mean( corrs, axis=0 )[1], label=str(get_lmlm( 1 ).flatten()) )
plt.plot( np.mean( corrs, axis=0 )[2], label=str(get_lmlm( 2 ).flatten()) )
plt.plot( np.mean( corrs, axis=0 )[3], label=str(get_lmlm( 3 ).flatten()) )
plt.plot( np.mean( corrs, axis=0 )[4], label=str(get_lmlm( 4 ).flatten()) )
plt.legend()

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(5):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(5,10):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(15,20):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(20,25):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(25,30):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)
float(at)
for i in range(30,35):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(get_lmlm( i ).flatten()) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
plt.clf()

x = np.arange(1,Nt/2)*float(at)
for i in range(35,36):
    plt.errorbar( x, np.abs(jk.mean()[i]), jk.err()[i], marker='x', label=str(i) )
plt.legend( fontsize=12, loc='right' )
plt.yscale("log")

# %%
def zero_noise( est, err ):
    for irow in np.arange( est.shape[0] ):
        lm1, lm2 = get_lmlm( irow )
        # print(lm1, lm2)
        if (lm1[0]==1 and lm2[0]==0) or (lm1[0]==0 and lm2[0]==1): # no mix
            est[irow] = 0.0
            err[irow] = 0.0
            # print(est[irow])
        elif lm1[0]==1 and lm2[0]==1:
            if lm1[1]!=lm2[1]: # no mix
                est[irow] = 0.0
                err[irow] = 0.0
                # print(est[irow])
    return est, err

# %%
# plt.clf()

# x = np.arange(1,Nt/2)*float(at)
# for i in range(jk.mean().shape[0]):
#     plt.errorbar( x, est[i], err[i], marker='x', label=str(i) )
# # plt.errorbar( x, jk.mean()[1], jk.err()[1], marker='x' )
# plt.yscale("log")
# plt.legend( ncol=4, fontsize=6, loc='right' )

# plt.savefig( desc+"_glue_all.pdf", bbox_inches="tight" )

# %%
jk.mean().shape
# Out:
# (256, 63)

# %%
nops
# Out:
# 16

# %%
corrs.shape
# Out:
# (4440, 256, 63)

# %%
mean_corr.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 mean_corr.shape
#
# NameError: name 'mean_corr' is not defined

# %%
mean_corr = np.mean(corrs, axis=0)

# %%
mean_corr = np.mean(corrs, axis=0)

# item 1: subtract vacuum <O_i><O_j> (full sample) for the diagnostic matCA below.
mean1pt = np.mean(F1pts, axis=0)
prod1pt = np.kron(mean1pt, mean1pt)
conn = mean_corr - prod1pt[:, None]

# conn, dummy = zero_noise( mean_corr, mean_corr )

matC1 = np.array(np.split( conn, nops, axis=0 ))[:nops1,:nops1]
matC = np.transpose(matC1, (-1, 0, -2))
matCT = np.transpose(matC, (0, 2, 1))
matCA = 0.5*(matC+matCT)

# %%
at=float(at)

# %%
t=trebase
sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
eigval, eigvec = np.linalg.eigh(matM)
Vrebase=eigvec

# %%
matCA.shape
# Out:
# (63, 16, 16)

# %%
eigvals_ = []
for t in range(1,tcut):
    sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
    matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
    matMtrunc = (Vrebase.T@matM@Vrebase)[-nops2:,-nops2:]
    # matMtrunc = (matM)[-nops2:,-nops2:]
    eigval, eigvec = np.linalg.eigh(matMtrunc)
    eigvals_.append( eigval )

eigvals = np.array(eigvals_)
-np.log(eigvals)/at
# Out:
# array([[2.48502469, 2.39809386, 2.25165654, 2.16228217, 2.02454311,
#         1.98465892, 1.91012351, 1.43944393],
#        [2.56935843, 2.54882151, 2.48277604, 2.2413678 , 2.07915263,
#         1.97123111, 1.85311776, 1.42927353],
#        [3.10258925, 2.64839383, 2.28592783, 2.20730842, 2.07770998,
#         1.86705101, 1.80653909, 1.39634462],
#        [4.53866932, 2.68287966, 2.45611188, 1.90447454, 1.59760104,
#         1.41201357, 1.31306716, 1.12238855]])

# %%
eigvals
# Out:
# array([[0.60834998, 0.61901933, 0.63741693, 0.64891312, 0.66703776,
#         0.67237989, 0.68247819, 0.74984498],
#        [0.59817514, 0.60063713, 0.60862363, 0.63872993, 0.65979208,
#         0.67418804, 0.69030376, 0.75137178],
#        [0.53766593, 0.58879408, 0.63306285, 0.64309573, 0.65998248,
#         0.6883828 , 0.69676449, 0.75633648],
#        [0.40343743, 0.58474704, 0.61187799, 0.68324969, 0.72649752,
#         0.75396999, 0.76903913, 0.79893339]])

# %%
plt.plot( -np.log(eigvals)/at, marker='o' )
plt.hlines( 1.6, 1.0, 2.0, ls='dashed' )
plt.ylim( 0, 5 )
# Out:
# (0.0, 5.0)

# %%
Nf
# Out:
# 2

# %%
# eigvals_ = []
# for t in range(1,tcut):
#     sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
#     matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
#     matMtrunc = (Vrebase.T@matM@Vrebase)[-nops2:,-nops2:]
#     matMtrunc = (matM)[-nops2:,-nops2:]
#     eigval, eigvec = np.linalg.eigh(matMtrunc)
#     eigvals_.append( eigval )

# eigvals = np.array(eigvals_)
# -np.log(eigvals)/at

# %%
eigvals
# Out:
# array([[0.60834998, 0.61901933, 0.63741693, 0.64891312, 0.66703776,
#         0.67237989, 0.68247819, 0.74984498],
#        [0.59817514, 0.60063713, 0.60862363, 0.63872993, 0.65979208,
#         0.67418804, 0.69030376, 0.75137178],
#        [0.53766593, 0.58879408, 0.63306285, 0.64309573, 0.65998248,
#         0.6883828 , 0.69676449, 0.75633648],
#        [0.40343743, 0.58474704, 0.61187799, 0.68324969, 0.72649752,
#         0.75396999, 0.76903913, 0.79893339]])

# %%
plt.plot( -np.log(eigvals)/at, marker='o' )

# plt.hlines( np.sqrt(2), 1.0, 2.0, ls='dashed' )
plt.hlines( 1.6, 1.0, 2.0, ls='dashed' )

plt.ylim( 0, 5 )
# Out:
# (0.0, 5.0)

# %%
np.log(eigvals[0]) / np.log(eigvals[1])
# Out:
# array([0.96717712, 0.94086379, 0.90691086, 0.96471546, 0.97373472,
#        1.00681189, 1.03076208, 1.00711579])

# %%
np.log(eigvals[0])/at, np.log(eigvals[1])/at
# Out:
# (array([-2.48502469, -2.39809386, -2.25165654, -2.16228217, -2.02454311,
#         -1.98465892, -1.91012351, -1.43944393]),
#  array([-2.56935843, -2.54882151, -2.48277604, -2.2413678 , -2.07915263,
#         -1.97123111, -1.85311776, -1.42927353]))

# %%
def get_eigvals( conn ):
    conn, dummy = zero_noise( conn, conn )
    matC1 = np.array(np.split( conn, nops, axis=0 ))[:nops1,:nops1]
    matC = np.transpose(matC1, (-1, 0, -2))
    matCT = np.transpose(matC, (0, 2, 1))
    matCA = 0.5*(matC+matCT)

    t=trebase
    sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
    matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
    eigval, eigvec = np.linalg.eigh(matM)
    Vrebase=eigvec

    eigvals_ = []
    for t in range(1,tcut):
        sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
        matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
        matMtrunc = (Vrebase.T@matM@Vrebase)[-nops2:,-nops2:]
        eigval, eigvec = np.linalg.eigh(matMtrunc)
        eigvals_.append( eigval )
    eigvals = np.array(eigvals_)

    return -np.log(eigvals)/at

# %%
def gevp(i, binsize, corr_):
    resmpld = np.delete(corr_, np.s_[i*binsize:(i+1)*binsize], axis=0)
    conn = np.mean(resmpld, axis=0)
    conn = vacuum_sub( conn, i, binsize )   # item 1: connected correlator
    return get_eigvals( conn )

# %%
jk = Jackknife( corrs.shape[0], 50 )
jk.set( gevp, corrs )
jk.do_it()

# %%
xx = np.arange(1,tcut)*at
for i in range(nops2):
    plt.errorbar( xx, jk.mean().T[i], jk.err().T[i] )

plt.xlabel("$t$")
plt.ylabel("$\\Delta_{\\rm eff}$")

plt.savefig( desc+"_gevpspectrum.pdf")

# %%
def twostates( t, m0, A, Dm ):
    return m0 + A*np.exp(-Dm*t)

def onestate( t, m0 ):
    return m0

# %%
i=nops2-1
plt.errorbar( xx, jk.mean().T[i], jk.err().T[i] )

# %%
iop=nops2-1
fitm=1
fitM=2

xx2=xx[fitm:fitM+1]
yy2=jk.mean().T[iop][fitm:fitM+1]
dyy2=jk.err().T[iop][fitm:fitM+1]

opt1=sp.optimize.curve_fit( onestate, xx2, yy2, sigma=dyy2, absolute_sigma=True )

# %%
opt1
# Out:
# (array([1.49064859]), array([[0.00300945]]))

# %%
dyy2
# Out:
# array([0.06893416, 0.09059317], dtype=float32)

# %%
def gevp_fit(i, binsize, corr_):
    resmpld = np.delete(corr_, np.s_[i*binsize:(i+1)*binsize], axis=0)
    conn = np.mean(resmpld, axis=0)
    conn = vacuum_sub( conn, i, binsize )   # item 1: connected correlator
    yy = get_eigvals( conn ).T
    # print(yy)

    yyy = yy[iop][fitm:fitM+1]
    # print(yyy)
    dyyy = dyy2

    opt = sp.optimize.curve_fit( onestate, xx2, yyy, sigma=dyyy, p0=opt1[0], absolute_sigma=True )
    # print(opt[0])
    # print(opt[0])

    return opt[0]

# %%
jk2 = Jackknife( corrs.shape[0], 1 )
jk2.set( gevp_fit, corrs )
jk2.do_it()

# %%
format_print_w_exact( np.sqrt(2.0), jk2.mean()[0], jk2.err()[0] )
# Out:
# '1.491(71): -1.070 sigma'

# %%
jk2.mean()
# Out:
# array([1.49064849])

# %%
onestate(xx, jk2.mean()[0] )
# Out:
# 1.4906484857445101

# %%
i=nops2-1
plt.errorbar( xx, jk.mean().T[i], jk.err().T[i], label=str((fitm+1)*float(at))+":"+str((fitM+1)*float(at)) )

plt.plot( xx, np.full(xx.shape[0], onestate(xx, jk2.mean()[0] )) )

plt.title(format_print_w_exact( np.sqrt(2.0), jk2.mean()[0], jk2.err()[0] ))
plt.legend()

plt.ylim(0.0,5.0)

plt.savefig( desc+"_fit_glue.pdf", bbox_inches="tight" )

# %%
plt.plot( -np.log(eigvals)/at, marker='o' )
plt.hlines( 1.4, 0.0, 1.5 )

# %%
plt.plot( -np.log(eigvals)/at, marker='o' )
plt.hlines( 1.4, 0.0, 1.5 )

# %%
def gevp(i, binsize, corr_):
    resmpld = np.delete(corr_, np.s_[i*binsize:(i+1)*binsize], axis=0)
    conn = np.mean(resmpld, axis=0)
    matC1 = np.array(np.split( conn, nops, axis=0 ))
    matC = np.transpose(matC1, (-1, 0, -2))
    matCT = np.transpose(matC, (0, 2, 1))
    matCA = 0.5*(matC+matCT)

    eigvals_ = []
    for t in range(1,tcut):
        sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
        matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
        eigval, eigvec = np.linalg.eigh(matM)
        eigvals_.append( eigval )
    eigvals = np.array(eigvals_)

    return -np.log(eigvals)/at

# %%
nbins=40

# %%
jk = Jackknife( corr.shape[0], int( corr.shape[0]/nbins ) )
jk.set( gevp, corr )
jk.do_it()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 jk = Jackknife( corr.shape[0], int( corr.shape[0]/nbins ) )
# ----> 2 jk.set( gevp, corr )
#       3 jk.do_it()
#
# Cell In[2], line 12, in Jackknife.set(self, func, list_of_data)
#      10 def set( self, func, list_of_data ):
#      11     for i in range( self.nbins ):
# ---> 12         self.jack_avg.append( func( i, self.binsize, list_of_data ) )
#
# Cell In[26], line 4, in gevp(i, binsize, corr_)
#       2 resmpld = np.delete(corr_, np.s_[i*binsize:(i+1)*binsize], axis=0)
#       3 conn = np.mean(resmpld, axis=0)
# ----> 4 matC1 = np.array(np.split( conn, nops, axis=0 ))
#       5 matC = np.transpose(matC1, (-1, 0, -2))
#       6 matCT = np.transpose(matC, (0, 2, 1))
#
# File ~/anaconda3/lib/python3.12/site-packages/numpy/lib/shape_base.py:864, in split(ary, indices_or_sections, axis)
#     862     N = ary.shape[axis]
#     863     if N % sections:
# --> 864         raise ValueError(
#     865             'array split does not result in an equal division') from None
#     866 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
xx = np.arange(1,tcut)*at
for i in range(nops):
    plt.errorbar( xx, jk.mean().T[i], jk.err().T[i] )

plt.xlabel("$t$")
plt.ylabel("$\\Delta_{\\rm eff}$")

plt.savefig("spectrum.pdf")

# %%
def twostates( t, m0, A, Dm ):
    return m0 + A*np.exp(-Dm*t)

def onestate( t, m0 ):
    return m0

# %%
i=nops-1
plt.errorbar( xx, jk.mean().T[i], jk.err().T[i] )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
iop=nops-1
fitm=2
fitM=4

xx2=xx[fitm:fitM]
yy2=jk.mean().T[iop][fitm:fitM]
dyy2=jk.err().T[iop][fitm:fitM]

opt1=sp.optimize.curve_fit( onestate, xx2, yy2, sigma=dyy2, absolute_sigma=True )

# %%
def gevp_fit(i, binsize, corr_):
    resmpld = np.delete(corr_, np.s_[i*binsize:(i+1)*binsize], axis=0)
    conn = np.mean(resmpld, axis=0)
    matC1 = np.array(np.split( conn, nops, axis=0 ))
    matC = np.transpose(matC1, (-1, 0, -2))
    matCT = np.transpose(matC, (0, 2, 1))
    matCA = 0.5*(matC+matCT)

    eigvals_ = []
    for t in range(1,tcut):
        sqrt_ct_inv = np.linalg.inv(sp.linalg.sqrtm(matCA[t]))
        matM = sqrt_ct_inv@matCA[t+dt]@sqrt_ct_inv
        eigval, eigvec = np.linalg.eigh(matM)
        eigvals_.append( eigval )
    eigvals = np.array(eigvals_)

    yy = (-np.log(eigvals)/at).T
    # print(yy)
    yyy = yy[iop][fitm:fitM]
    # print(yyy)
    dyyy = dyy2

    opt = sp.optimize.curve_fit( onestate, xx2, yyy, sigma=dyyy, p0=opt1[0], absolute_sigma=True )
    # print(opt[0])

    return opt[0]

# %%
jk2 = Jackknife( corr.shape[0], int( corr.shape[0]/nbins ) )
jk2.set( gevp_fit, corr )
jk2.do_it()

# %%
format_print_w_exact( np.sqrt(2.0), jk2.mean()[0], jk2.err()[0] )
# Out:
# '1.412(37): 0.064 sigma'
