# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
font = {'size'   : 12}
plt.rc('font', **font)

colors={
    2:'#006BA4',
    3:'#FF800E',
    4:'#ABABAB',
    "A":'#FFBC79',
    "B":'#5F9ED1',
    "C":'#C85200',
    6:'#898989',
    7:'#A2C8EC',
    8:'#595959',
    9:'#CFCFCF'
}

markers={
    2:"o", 
    3:"d", 
    4:"v", 
    "A":"x", 
    "B":"<", 
    "C":"^", 
}

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica",
    'font.size'  : 22
})
plt.rc('font',family='Times New Roman')

# %%
k1 = np.loadtxt("ev_k1free.dat")
k2 = np.loadtxt("ev_k2free.dat")
k4 = np.loadtxt("ev_k4free.dat")
k8 = np.loadtxt("ev_k8free.dat")
k16 = np.loadtxt("ev_k16free.dat")

# %%
k1s = k1[k1[:,0].argsort()]
k2s = k2[k2[:,0].argsort()]
k4s = k4[k4[:,0].argsort()]
k8s = k8[k8[:,0].argsort()]
k16s = k16[k16[:,0].argsort()]

# %%
ev1 = np.array([
    [k1s[0][0]+1.0, k1s[0][1]],
    [k2s[0][0]+1.0, k2s[0][1]],
    [k4s[0][0]+1.0, k4s[0][1]],
    [k8s[0][0]+1.0, k8s[0][1]],
    [k16s[0][0]+1.0, k16s[0][1]],
])

# %%
ks = np.array([1, 2, 4, 8, 16])

# %%
plt.plot( 1.0/ks, ev1.T[0],
        marker="x",  label="spec $D_{{\\rm ov}}$")

plt.plot( 1.0/ks, 0.02/ks**2, ls="dashed", label="quad scaling" )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("$1/L$")
plt.ylabel("${\\rm Re}\, \\lambda_{1/2}$")

plt.tight_layout()
plt.savefig("figs/Re.pdf", bbox_inches='tight')

# %%
plt.plot( 1.0/ks, np.abs(ev1.T[1]),
        marker="x", label="spec $D_{{\\rm ov}}$")

plt.plot( 1.0/ks, 0.2/ks, ls="dashed", label="linear scaling" )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("$1/L$")
plt.ylabel("${\\rm Im}\, \\lambda_{1/2}$")

plt.tight_layout()
plt.legend()

plt.savefig("figs/Im.pdf", bbox_inches='tight')

# %%
pos = k16s.T[1] > 0

# %%
plt.plot( (1.0+k16s.T[0][pos])/np.abs(1.0+k16s.T[0][0]), ls="none", marker="." )
plt.xlim(-1, 43)
plt.ylim(0, 50)

plt.title("$L=16$ (refinement 16)")

plt.ylabel("${\\rm Re}\, \\lambda_{j} / {\\rm Re}\, \\lambda_{1/2}$")

plt.tight_layout()
# plt.legend()
plt.savefig("figs/Re16.pdf", bbox_inches='tight')

# %%
plt.plot( k16s.T[1][pos]/np.abs(k16s.T[1][0]), ls="none", marker="." )
plt.xlim(-1, 43)
plt.ylim(0, 8)

plt.title("$L=16$ (refinement 16)")

plt.ylabel("${\\rm Im}\, \\lambda_{j} / {\\rm Im}\, \\lambda_{1/2}$")

plt.tight_layout()
# plt.legend()
plt.savefig("figs/Im16.pdf", bbox_inches='tight')
