# %%
import os
import numpy as np
import math
import matplotlib.pyplot as plt

import scipy as sp
import scipy.linalg
import scipy.optimize

import glob

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica",
    'font.size'  : 20
})

# %%
T=12
Nt=168

# %%
l1_1 = np.loadtxt("ov_prop_temporal_L1_Nt"+str(Nt)+"_T"+str(T)+".000000.dat").T[1,::2]
l2_1 = np.loadtxt("ov_prop_temporal_L2_Nt"+str(Nt)+"_T"+str(T)+".000000.dat").T[1,::2]
l4_1 = np.loadtxt("ov_prop_temporal_L4_Nt"+str(Nt)+"_T"+str(T)+".000000.dat").T[1,::2]
l8_1 = np.loadtxt("ov_prop_temporal_L8_Nt"+str(Nt)+"_T"+str(T)+".000000.dat").T[1,::2]

# %%
def Gt( t, nmax, T ):
    res = 0.0
    for n in range(nmax):
        res += (n+1.0) * ( np.exp( -(n+1.0)*t ) + np.exp( -(n+1.0)*(T-t) ) )
    res /= 4.0*np.pi
    return res

# %%
ts=T*np.arange(100)/100
Gts = np.array([Gt( t, 10, T ) for t in ts])

# %%
def fitter( t, z ):
    return np.log( z * Gt(t, nmax, T) )

# %%
xx=T * np.arange(Nt)/Nt
yy = l1_1

# %%
for nmax in np.arange(1, 100):
    opt = sp.optimize.curve_fit( fitter, xx, np.log(yy), full_output=True, absolute_sigma=True, p0=1 )
    diff = np.sum( opt[2]['fvec']**2 )
    print(nmax, diff/(l1_1.shape[0]-2), [opt[0][0], np.sqrt(opt[1][0,0])])
# Out:
# 1 0.4247756450851322 [1.519352854552662, 0.11722031770241306]
# 2 0.1615926299613074 [1.1972859159953277, 0.09237261412735018]
# 3 0.07548839414667993 [1.0921736315118409, 0.08426245833471177]
# 4 0.04262856235437022 [1.0395387403415177, 0.08020213447249785]
# 5 0.030467487697788707 [1.0078177879117025, 0.07775483063371418]
# 6 0.0275716494365147 [0.9865760610887792, 0.07611599574231967]
# 7 0.02915901888794632 [0.9713418394507921, 0.07494064317004485]
# 8 0.032991100388839956 [0.9598744026422202, 0.07405589063437759]
# 9 0.0379370836363795 [0.9509255057932939, 0.07336543333847732]
# 10 0.04339535450294687 [0.9437441476900869, 0.07281133148282702]
# 11 0.04903505166256052 [0.9378511902857715, 0.07235662369007166]
# 12 0.054671190374298954 [0.9329264587825924, 0.07197660996305397]
# 13 0.06020051672557617 [0.9287478240630695, 0.0716541551864538]
# 14 0.06556691416634138 [0.9251563179977539, 0.07137699722123247]
# 15 0.07074200301238483 [0.9220351640987496, 0.0711361273388799]
# 16 0.07571391197562219 [0.9192966438502773, 0.07092477840095308]
# 17 0.0804806137570292 [0.9168735817513272, 0.07073776897621854]
# 18 0.08504589122634428 [0.9147136667378692, 0.07057106318181547]
# 19 0.08941686040033206 [0.9127755491839682, 0.0704214720501628]
# 61 0.18701762618661422 [0.8874196112784454, 0.06846386101526983]
# 62 0.18841782780905986 [0.8872046106456648, 0.06844725634904018]
# 63 0.18979919380355792 [0.8869950615836093, 0.06843107218378172]
# 64 0.1911624472978066 [0.8867907021718098, 0.06841529000826627]
# 65 0.19250827417791744 [0.8865912965268838, 0.0683998895261968]
# 66 0.19383732529214853 [0.886396612915973, 0.06838485366710613]
# 67 0.19515021850063657 [0.8862064402292642, 0.06837016597915095]
# 68 0.1964475405840783 [0.8860205769001743, 0.06835581123290688]
# 69 0.19772984902307844 [0.8858388350878389, 0.0683417748754613]
# 70 0.198997673658769 [0.8856610358496236, 0.06832804229363793]
# 71 0.20025151824430013 [0.8854870094789423, 0.06831460181294635]
# 72 0.20149186189590373 [0.8853165991575626, 0.06830144023265022]
# 73 0.20271916045141547 [0.8851496542787058, 0.06828854601359223]
# 74 0.2039338477434109 [0.8849860328734047, 0.06827590878667145]
# 75 0.2051363367934538 [0.8848256015486258, 0.06826351736464248]
# 76 0.20632702093336067 [0.8846682297516424, 0.06825136274089784]
# 77 0.20750627485885276 [0.8845138036121852, 0.06823943517248687]
# 78 0.20867445562048897 [0.8843622026743017, 0.06822772640484934]
# 79 0.2098319035563364 [0.884213322543914, 0.06821622702367296]
# 80 0.21097894317045132 [0.8840670610785952, 0.06820492997967459]
# 81 0.21211588396088887 [0.8839233175734623, 0.06819382816388159]
# 82 0.21324302120064687 [0.8837820044137624, 0.06818291314924738]
# 83 0.2143606366746615 [0.8836430307099202, 0.06817217858849797]
# 84 0.21546899937571992 [0.8835063134929532, 0.06816161919580521]
# 85 0.21656836616191918 [0.8833717739408922, 0.06815122723832916]
# 86 0.21765898237809303 [0.8832393345185098, 0.06814099735700602]
# 87 0.21874108244344118 [0.8831089259771988, 0.06813092460225674]
# 88 0.21981489040742067 [0.8829804796074004, 0.06812100326723997]
# 89 0.22088062047580698 [0.882853927602354, 0.06811122831206663]
# 90 0.22193847750869025 [0.8827292103098203, 0.06810159464382141]
# 91 0.22298865749204583 [0.8826062689052647, 0.06809209885237823]
# 92 0.22403134798440066 [0.8824850430892983, 0.06808273470631557]
# 93 0.22506672854001394 [0.8823654839718452, 0.0680734994683708]
# 94 0.22609497110989044 [0.8822475344445762, 0.06806438927977936]
# 95 0.22711624042186182 [0.8821311492442614, 0.06805539926036197]
# 96 0.22813069434088623 [0.8820162810030384, 0.06804652663269023]
# 97 0.22913848421064606 [0.8819028838142026, 0.06803776723772116]
# 98 0.23013975517745455 [0.8817909151502228, 0.06802911825114828]
# 99 0.23113464649741938 [0.8816803320848716, 0.06802057650824019]

# %%
ts=12*np.arange(1000)/1000
Gts = np.array([Gt( t, 4000, 12 ) for t in ts])

# %%
np.savetxt("ferm_exact.dat", np.array([ts, Gts]).T )
